# %%
import pandas as pd
import numpy as np

df = pd.read_csv("login_data.csv")
df.head()

# %%
df.info()
df.describe()

# %%
# TODO:
# Define a binary column "suspicious"
# Hint: use Is Attack IP and Is Account Takeover

# %%
# TODO:
# Select meaningful features:
# Country, Device Type, Browser, OS, ASN, RTT, hour, etc

features = [
    # fill
]

X = df[features]
y = df["suspicious"]

# %%
from sklearn.preprocessing import LabelEncoder

encoders = {}

# TODO:
# Loop through categorical columns
# Encode them
# Store encoders in dictionary

# %%
from sklearn.model_selection import train_test_split

# TODO:
# Split X and y into train and test

# %%
from sklearn.ensemble import RandomForestClassifier

# TODO:
# Initialize model
# Train on training data

# %%
from sklearn.metrics import accuracy_score, classification_report

# TODO:
# Predict on test set
# Print accuracy
# Print classification report

# %%
import joblib

# TODO:
# Save model
# Save encoders
